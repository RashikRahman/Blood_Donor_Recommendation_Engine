# %%
import pandas as pd 
import random

# %%
df = pd.read_csv('Donor.csv')

# %%
df.head()
# Out:
#             Name Blood Group      Phone District          Location  \
# 0     Arif Hasan          A+  171000011    Dhaka  Dhaka Cantonment
# 1    Zahid Hasan          A-  171000012    Dhaka  Dhaka Cantonment
# 2  Rafique Uddin          B-  171000013    Dhaka  Dhaka Cantonment
# 3    Afsana Mimi          O+  171000014    Dhaka           Dhamrai
# 4    Akash Ahmed          B+  171000015    Dhaka           Dhamrai
#
#    Postal Code Donate Request Availability
# 0         1200      Y       N            Y
# 1         1200      Y       N            Y
# 2         1200      Y       N            Y
# 3         1350      Y       N            Y
# 4         1351      Y       N            Y

# %%
df.shape
# Out:
# (109, 9)

# %%
df['Request']=random.sample(range(30, 140), 109) 
df['Donate']= df['Request'] - random.sample(range(1, 25), 1)

# %%
df.head()
# Out:
#             Name Blood Group      Phone District          Location  \
# 0     Arif Hasan          A+  171000011    Dhaka  Dhaka Cantonment
# 1    Zahid Hasan          A-  171000012    Dhaka  Dhaka Cantonment
# 2  Rafique Uddin          B-  171000013    Dhaka  Dhaka Cantonment
# 3    Afsana Mimi          O+  171000014    Dhaka           Dhamrai
# 4    Akash Ahmed          B+  171000015    Dhaka           Dhamrai
#
#    Postal Code  Donate  Request Availability
# 0         1200      35       56            Y
# 1         1200      29       50            Y
# 2         1200     105      126            Y
# 3         1350      89      110            Y
# 4         1351      30       51            Y

# %%
df['Availability'] = df['Availability'].map({'Y':1,'N':0})

# %%
df.head()
# Out:
#             Name Blood Group      Phone District          Location  \
# 0     Arif Hasan          A+  171000011    Dhaka  Dhaka Cantonment
# 1    Zahid Hasan          A-  171000012    Dhaka  Dhaka Cantonment
# 2  Rafique Uddin          B-  171000013    Dhaka  Dhaka Cantonment
# 3    Afsana Mimi          O+  171000014    Dhaka           Dhamrai
# 4    Akash Ahmed          B+  171000015    Dhaka           Dhamrai
#
#    Postal Code  Donate  Request  Availability
# 0         1200      35       56             1
# 1         1200      29       50             1
# 2         1200     105      126             1
# 3         1350      89      110             1
# 4         1351      30       51             1

# %%
df.describe(include='O')
# Out:
#                 Name Blood Group District          Location
# count            109         109      109               109
# unique           109           8        1                50
# top     Lemon Rahman          B+    Dhaka  Dhaka Cantonment
# freq               1          23      109                 4

# %%
df.to_csv('donor_data.csv', index=False)

# %%
df = pd.read_csv('donor_data.csv')
df.head()
# Out:
#             Name Blood Group      Phone District          Location  \
# 0     Arif Hasan          A+  171000011    Dhaka  Dhaka Cantonment
# 1    Zahid Hasan          A-  171000012    Dhaka  Dhaka Cantonment
# 2  Rafique Uddin          B-  171000013    Dhaka  Dhaka Cantonment
# 3    Afsana Mimi          O+  171000014    Dhaka           Dhamrai
# 4    Akash Ahmed          B+  171000015    Dhaka           Dhamrai
#
#    Postal Code  Donate  Request  Availability
# 0         1200      35       56             1
# 1         1200      29       50             1
# 2         1200     105      126             1
# 3         1350      89      110             1
# 4         1351      30       51             1

# %%
df['rating'] = df['Donate']/df['Request']

# %%
df = df.sort_values(by='rating',ascending=False)
df
# Out:
#                  Name Blood Group      Phone District              Location  \
# 52     HM Abdul Wahab          O+  171000063    Dhaka  Uttara Model TownTSO
# 37       Foysal Ahmed          O-  171000048    Dhaka            Amin Bazar
# 41  Habibullah Sheikh         AB-  171000052    Dhaka   Kashem Cotton Mills
# 78   Khadijatul Kubra         AB+  171000089    Dhaka           DilkushaTSO
# 44         Haani Khan          A-  171000055    Dhaka     Savar Canttonment
# ..                ...         ...        ...      ...                   ...
# 68        Jewel Islam          B+  171000079    Dhaka      Dhaka Jute Mills
# 61      Jakir Hossain          O+  171000072    Dhaka    Gulshan Model Town
# 53    Hossainul Abrar          A+  171000064    Dhaka  Uttara Model TownTSO
# 85           MD Hasan          B+  171000096    Dhaka             Kalabagan
# 45     Harunor Rashid         AB+  171000056    Dhaka         Saver P.A.T.C
#
#     Postal Code  Donate  Request  Availability    rating
# 52         1230     118      139             1  0.848921
# 37         1348     117      138             0  0.847826
# 41         1346     116      137             1  0.846715
# 78         1223     115      136             1  0.845588
# 44         1344     114      135             1  0.844444
# ..          ...     ...      ...           ...       ...
# 68         1311      13       34             1  0.382353
# 61         1212      12       33             1  0.363636
# 53         1230      11       32             1  0.343750
# 85         1205      10       31             1  0.322581
# 45         1343       9       30             1  0.300000
#
# [109 rows x 10 columns]

# %%
blood = 'B-'
top10 = df[df['Blood Group']==blood] 
top10[['Name','Blood Group','Phone']]
# Out:
#                Name Blood Group      Phone
# 2     Rafique Uddin          B-  171000013
# 59     Jaahid Hasan          B-  171000070
# 21    Dilruba Jahan          B-  171000032
# 28      Fazle Rabbi          B-  171000039
# 30     Faria Ulfath          B-  171000041
# 39       Golam Azam          B-  171000050
# 105  Rahmanul Karim          B-  171000116
# 40      Habib Ahmed          B-  171000051
# 71      Jyoti Tithi          B-  171000082
# 17        Arjun Roy          B-  171000028

# %%
your_loc = 1207
blood = 'B-'
near_you = df[ (df['Blood Group']==blood) & ((df['Postal Code']<your_loc+8) & (df['Postal Code']>your_loc-8)) ] 
near_you[['Name','Blood Group','Phone']]
# Out:
#              Name Blood Group      Phone
# 2   Rafique Uddin          B-  171000013
# 59   Jaahid Hasan          B-  171000070
# 21  Dilruba Jahan          B-  171000032

# %%
all_donor = df.copy()
all_donor[['Name','Blood Group','Phone']].head()
# Out:
#                  Name Blood Group      Phone
# 52     HM Abdul Wahab          O+  171000063
# 37       Foysal Ahmed          O-  171000048
# 41  Habibullah Sheikh         AB-  171000052
# 78   Khadijatul Kubra         AB+  171000089
# 44         Haani Khan          A-  171000055

# %%
# save data in json format
import json
result = df.to_json(orient="columns")
parsed = json.loads(result)

with open('donor_data.json', 'w') as f:
    f.write(json.dumps(parsed))

# %% [markdown]
# ## Script Demo

# %%
import Engine as en

# %%
en.top10('B-', 'Dhaka')
# Out:
#                Name Blood Group      Phone
# 2     Rafique Uddin          B-  171000013
# 21    Dilruba Jahan          B-  171000032
# 28      Fazle Rabbi          B-  171000039
# 30     Faria Ulfath          B-  171000041
# 39       Golam Azam          B-  171000050
# 105  Rahmanul Karim          B-  171000116
# 40      Habib Ahmed          B-  171000051
# 71      Jyoti Tithi          B-  171000082
# 17        Arjun Roy          B-  171000028

# %%
en.near_you('B+', 'Dhaka', 1205)
# Out:
#                Name Blood Group      Phone
# 48    Hasibuj Jaman          B+  171000059
# 100     Naina Kabir          B+  171000111
# 101   Nayema Rahman          B+  171000112
# 73    Kalpona Islam          B+  171000084
# 33   Farjana Laboni          B+  171000044
# 85         MD Hasan          B+  171000096
