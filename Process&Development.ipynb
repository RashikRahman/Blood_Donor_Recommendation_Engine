# %%
import pandas as pd

# %%
df = pd.read_csv('Donor.csv')

# %%
df.head()
# Out:
#             Name Blood Group      Phone District          Location  \
# 0     Arif Hasan          A+  171000011    Dhaka  Dhaka Cantonment
# 1    Zahid Hasan          A-  171000012    Dhaka  Dhaka Cantonment
# 2  Rafique Uddin          B-  171000013    Dhaka  Dhaka Cantonment
# 3    Afsana Mimi          O+  171000014    Dhaka           Dhamrai
# 4    Akash Ahmed          B+  171000015    Dhaka           Dhamrai
#
#    Postal Code Donate Request Availability
# 0         1200      Y       N            Y
# 1         1200      Y       N            Y
# 2         1200      Y       N            Y
# 3         1350      Y       N            Y
# 4         1351      Y       N            Y

# %%
df.shape
# Out:
# (109, 9)

# %%
import random
df['Request']=random.sample(range(30, 140), 109) 
df['Donate']= df['Request'] - random.sample(range(1, 25), 1)

# %%
df.head()
# Out:
#             Name Blood Group      Phone District          Location  \
# 0     Arif Hasan          A+  171000011    Dhaka  Dhaka Cantonment
# 1    Zahid Hasan          A-  171000012    Dhaka  Dhaka Cantonment
# 2  Rafique Uddin          B-  171000013    Dhaka  Dhaka Cantonment
# 3    Afsana Mimi          O+  171000014    Dhaka           Dhamrai
# 4    Akash Ahmed          B+  171000015    Dhaka           Dhamrai
#
#    Postal Code  Donate  Request Availability
# 0         1200     116      117            Y
# 1         1200     138      139            Y
# 2         1200      36       37            Y
# 3         1350      85       86            Y
# 4         1351     112      113            Y

# %%
df['Availability'] = df['Availability'].map({'Y':1,'N':0})

# %%
df.head()
# Out:
#             Name Blood Group      Phone District          Location  \
# 0     Arif Hasan          A+  171000011    Dhaka  Dhaka Cantonment
# 1    Zahid Hasan          A-  171000012    Dhaka  Dhaka Cantonment
# 2  Rafique Uddin          B-  171000013    Dhaka  Dhaka Cantonment
# 3    Afsana Mimi          O+  171000014    Dhaka           Dhamrai
# 4    Akash Ahmed          B+  171000015    Dhaka           Dhamrai
#
#    Postal Code  Donate  Request  Availability
# 0         1200     116      117             1
# 1         1200     138      139             1
# 2         1200      36       37             1
# 3         1350      85       86             1
# 4         1351     112      113             1

# %%
df.describe(include='O')
# Out:
#                Name Blood Group District Location
# count           109         109      109      109
# unique          109           8        1       50
# top     Jyoti Tithi          B+    Dhaka  Dhamrai
# freq              1          23      109        4

# %%
df.to_csv('donor_data.csv', index=False)

# %%
df = pd.read_csv('donor_data.csv')
df.head()
# Out:
#             Name Blood Group      Phone District          Location  \
# 0     Arif Hasan          A+  171000011    Dhaka  Dhaka Cantonment
# 1    Zahid Hasan          A-  171000012    Dhaka  Dhaka Cantonment
# 2  Rafique Uddin          B-  171000013    Dhaka  Dhaka Cantonment
# 3    Afsana Mimi          O+  171000014    Dhaka           Dhamrai
# 4    Akash Ahmed          B+  171000015    Dhaka           Dhamrai
#
#    Postal Code  Donate  Request  Availability
# 0         1200     116      117             1
# 1         1200     138      139             1
# 2         1200      36       37             1
# 3         1350      85       86             1
# 4         1351     112      113             1

# %%
df['rating'] = df['Donate']/df['Request']

# %%
df = df.sort_values(by='rating',ascending=False)
df
# Out:
#              Name Blood Group      Phone District             Location  \
# 1     Zahid Hasan          A-  171000012    Dhaka     Dhaka Cantonment
# 97   Musfika Rifa          B+  171000108    Dhaka        Saver P.A.T.C
# 30   Faria Ulfath          B-  171000041    Dhaka             Hasnabad
# 77    Kazi Istiak          B+  171000088    Dhaka       BangabhabanTSO
# 23    Emon Rahman          A-  171000034    Dhaka  Mohammadpur Housing
# ..            ...         ...        ...      ...                  ...
# 47     Hasan Imam          B+  171000058    Dhaka       Dhaka Sadar HO
# 57    Iqbal Hasan          A+  171000068    Dhaka            Dhanmondi
# 20  Diganta Ahmed          B+  171000031    Dhaka          KhilkhetTSO
# 93  Maliha Mumtaz          O+  171000104    Dhaka  Kashem Cotton Mills
# 12  Abdus Sobahan          B+  171000023    Dhaka              Joypara
#
#     Postal Code  Donate  Request  Availability    rating
# 1          1200     138      139             1  0.992806
# 97         1343     137      138             0  0.992754
# 30         1321     136      137             1  0.992701
# 77         1222     135      136             1  0.992647
# 23         1207     134      135             1  0.992593
# ..          ...     ...      ...           ...       ...
# 47         1100      33       34             1  0.970588
# 57         1209      32       33             0  0.969697
# 20         1229      31       32             1  0.968750
# 93         1346      30       31             1  0.967742
# 12         1331      29       30             1  0.966667
#
# [109 rows x 10 columns]

# %%
blood = 'B-'
top10 = df[df['Blood Group']==blood] 
top10[['Name','Blood Group','Phone']]
# Out:
#                Name Blood Group      Phone
# 30     Faria Ulfath          B-  171000041
# 21    Dilruba Jahan          B-  171000032
# 59     Jaahid Hasan          B-  171000070
# 105  Rahmanul Karim          B-  171000116
# 40      Habib Ahmed          B-  171000051
# 71      Jyoti Tithi          B-  171000082
# 28      Fazle Rabbi          B-  171000039
# 17        Arjun Roy          B-  171000028
# 39       Golam Azam          B-  171000050
# 2     Rafique Uddin          B-  171000013

# %%
your_loc = 1207
blood = 'B-'
near_you = df[ (df['Blood Group']==blood) & ((df['Postal Code']<your_loc+8) & (df['Postal Code']>your_loc-8)) ] 
near_you[['Name','Blood Group','Phone']]
# Out:
#              Name Blood Group      Phone
# 21  Dilruba Jahan          B-  171000032
# 59   Jaahid Hasan          B-  171000070
# 2   Rafique Uddin          B-  171000013

# %%
all_donor = df.copy()
all_donor[['Name','Blood Group','Phone']].head()
# Out:
#             Name Blood Group      Phone
# 1    Zahid Hasan          A-  171000012
# 97  Musfika Rifa          B+  171000108
# 30  Faria Ulfath          B-  171000041
# 77   Kazi Istiak          B+  171000088
# 23   Emon Rahman          A-  171000034

# %% [markdown]
# ## Script Demo

# %%
import Engine as en

# %%
en.top10('B-', 'Dhaka')
# Out:
#                Name Blood Group      Phone
# 30     Faria Ulfath          B-  171000041
# 21    Dilruba Jahan          B-  171000032
# 105  Rahmanul Karim          B-  171000116
# 40      Habib Ahmed          B-  171000051
# 71      Jyoti Tithi          B-  171000082
# 28      Fazle Rabbi          B-  171000039
# 17        Arjun Roy          B-  171000028
# 39       Golam Azam          B-  171000050
# 2     Rafique Uddin          B-  171000013

# %%
en.near_you('B-', 'Dhaka', 1207)
# Out:
#              Name Blood Group      Phone
# 2   Rafique Uddin          B-  171000013
# 21  Dilruba Jahan          B-  171000032
